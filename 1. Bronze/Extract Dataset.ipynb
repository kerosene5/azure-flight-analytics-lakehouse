# %%
# %pip install kaggle
# Out:
# ...
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
download_path_zipped = "/Volumes/databricks_flight_status_prediction/default/landing/flights/zipped/"
dbutils.fs.mkdirs(download_path_zipped)

download_path_unzipped = "/Volumes/databricks_flight_status_prediction/default/landing/flights/unzipped/"
dbutils.fs.mkdirs(download_path_unzipped)

# landing_path = "abfss://landing@storageforfsp.dfs.core.windows.net/flights/"
# dbutils.fs.ls(landing_path)
# Out:
# True

# %%
import os

os.environ['KAGGLE_USERNAME'] = "velociper"
os.environ['KAGGLE_KEY'] = "KGAT_a0be87eff7355c48a6dc895bde62cce5"

# %%
# !kaggle datasets download -d robikscube/flight-delay-dataset-20182022 -f Airlines.csv -p {download_path_unzipped}
# !kaggle datasets download -d robikscube/flight-delay-dataset-20182022 -f Combined_Flights_2018.csv -p {download_path_zipped} 
# !kaggle datasets download -d robikscube/flight-delay-dataset-20182022 -f Combined_Flights_2019.csv -p {download_path_zipped}  
# !kaggle datasets download -d robikscube/flight-delay-dataset-20182022 -f Combined_Flights_2020.csv -p {download_path_zipped} 
# !kaggle datasets download -d robikscube/flight-delay-dataset-20182022 -f Combined_Flights_2021.csv -p {download_path_zipped}  
# !kaggle datasets download -d robikscube/flight-delay-dataset-20182022 -f Combined_Flights_2022.csv -p {download_path_zipped}
# Out:
# Dataset URL: https://www.kaggle.com/datasets/robikscube/flight-delay-dataset-20182022
# License(s): CC0-1.0
# ...
# 100%|██████████████████████████████████████| 38.1k/38.1k [00:00<00:00, 296kB/s]
#
# Dataset URL: https://www.kaggle.com/datasets/robikscube/flight-delay-dataset-20182022
# License(s): CC0-1.0
# ...
# 100%|███████████████████████████████████████| 303M/303M [00:17<00:00, 18.5MB/s]
#
# Dataset URL: https://www.kaggle.com/datasets/robikscube/flight-delay-dataset-20182022
# License(s): CC0-1.0
# ...
# 100%|███████████████████████████████████████| 421M/421M [00:20<00:00, 21.3MB/s]
#
# Dataset URL: https://www.kaggle.com/datasets/robikscube/flight-delay-dataset-20182022
# License(s): CC0-1.0
# ...
# 100%|███████████████████████████████████████| 250M/250M [00:13<00:00, 19.5MB/s]
#
# Dataset URL: https://www.kaggle.com/datasets/robikscube/flight-delay-dataset-20182022
# License(s): CC0-1.0
# ...
# 100%|███████████████████████████████████████| 330M/330M [00:19<00:00, 17.4MB/s]
#
# ...

# %%
# %sh

unzip -o \
/Volumes/databricks_flight_status_prediction/default/landing/flights/zipped/Combined_Flights_2018.csv.zip \
-d /Volumes/databricks_flight_status_prediction/default/landing/flights/unzipped

unzip -o \
/Volumes/databricks_flight_status_prediction/default/landing/flights/zipped/Combined_Flights_2019.csv.zip \
-d /Volumes/databricks_flight_status_prediction/default/landing/flights/unzipped

unzip -o \
/Volumes/databricks_flight_status_prediction/default/landing/flights/zipped/Combined_Flights_2020.csv.zip \
-d /Volumes/databricks_flight_status_prediction/default/landing/flights/unzipped

unzip -o \
/Volumes/databricks_flight_status_prediction/default/landing/flights/zipped/Combined_Flights_2021.csv.zip \
-d /Volumes/databricks_flight_status_prediction/default/landing/flights/unzipped

unzip -o \
/Volumes/databricks_flight_status_prediction/default/landing/flights/zipped/Combined_Flights_2022.csv.zip \
-d /Volumes/databricks_flight_status_prediction/default/landing/flights/unzipped
# Out:
# Archive:  /Volumes/databricks_flight_status_prediction/default/landing/flights/zipped/Combined_Flights_2018.csv.zip
#   inflating: /Volumes/databricks_flight_status_prediction/default/landing/flights/unzipped/Combined_Flights_2018.csv
# Archive:  /Volumes/databricks_flight_status_prediction/default/landing/flights/zipped/Combined_Flights_2019.csv.zip
#   inflating: /Volumes/databricks_flight_status_prediction/default/landing/flights/unzipped/Combined_Flights_2019.csv
# Archive:  /Volumes/databricks_flight_status_prediction/default/landing/flights/zipped/Combined_Flights_2020.csv.zip
#   inflating: /Volumes/databricks_flight_status_prediction/default/landing/flights/unzipped/Combined_Flights_2020.csv
# Archive:  /Volumes/databricks_flight_status_prediction/default/landing/flights/zipped/Combined_Flights_2021.csv.zip
#   inflating: /Volumes/databricks_flight_status_prediction/default/landing/flights/unzipped/Combined_Flights_2021.csv
# ...
